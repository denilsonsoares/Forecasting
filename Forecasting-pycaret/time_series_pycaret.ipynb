# %%
import pandas as pd
import numpy as nump
data = pd.read_excel('PVC.xls', sheet_name='Para 2024')
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date  PVC BRL/tonne
# 0 2023-01-06       5512.549
# 1 2023-01-13       5349.321
# 2 2023-01-20       5463.852
# 3 2023-01-27       5346.214
# 4 2023-02-03       5372.849

# %%
# create 12 month moving average
data['MA12'] = data['PVC BRL/tonne'].rolling(12).mean()

# plot the data and MA
import plotly.express as px
fig = px.line(data, x="Date", y=["PVC BRL/tonne", "MA12"], template = 'plotly_dark')
fig.show()
# Out:
# <div>                            <div id="00687342-ca3e-4fbe-a372-b18942e01eaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00687342-ca3e-4fbe-a372-b18942e01eaa")) {                    Plotly.newPlot(                        "00687342-ca3e-4fbe-a372-b18942e01eaa",                        [{"hovertemplate":"variable=PVC BRL\u002ftonne\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PVC BRL\u002ftonne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PVC BRL\u002ftonne","orientation":"v","showlegend":true,"x":["2023-01-06T00:00:00","2023-01-13T00:00:00","2023-01-20T00:00:00","2023-01-27T00:00:00","2023-02-03T00:00:00","2023-02-10T00:00:00","2023-02-17
# ...

# %%
from pycaret.time_series import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from pycaret.time_series import *
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\time_series\__init__.py:1
# ----> 1 from pycaret.time_series.forecasting.oop import TSForecastingExperiment
#       2 from pycaret.time_series.forecasting.functional import (
#       3     setup,
#       4     create_model,
#    (...)
#      25     check_stats,
#      26 )
#      28 __all__ = [
#      29     "TSForecastingExperiment",
#      30     "setup",
#    (...)
#      52     "check_stats",
#      53 ]
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\time_series\forecasting\oop.py:16
#      14 from sklearn.base import clone
#      15 from sktime.forecasting.base import ForecastingHorizon
# ---> 16 from sktime.forecasting.model_selection import (
# ...

# %%
ts = setup(data, fh=150, fold_strategy='sliding')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ts = setup(data, fh=150, fold_strategy='sliding')
#
# NameError: name 'setup' is not defined
