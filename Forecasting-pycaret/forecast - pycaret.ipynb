# %% [markdown]
# # Pycaret

# %%
import pandas as pd
import numpy as nump
data = pd.read_excel('PVC.xls', sheet_name='Para 2024')
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date  PVC BRL/tonne
# 0 2023-01-06       5512.549
# 1 2023-01-13       5349.321
# 2 2023-01-20       5463.852
# 3 2023-01-27       5346.214
# 4 2023-02-03       5372.849

# %%
# create 12 month moving average
data['MA12'] = data['PVC BRL/tonne'].rolling(12).mean()

# plot the data and MA
import plotly.express as px
fig = px.line(data, x="Date", y=["PVC BRL/tonne", "MA12"], template = 'plotly_dark')
fig.show()
# Out:
# <div>                            <div id="bc733c51-ea90-4750-9ab5-8b0816d37dde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc733c51-ea90-4750-9ab5-8b0816d37dde")) {                    Plotly.newPlot(                        "bc733c51-ea90-4750-9ab5-8b0816d37dde",                        [{"hovertemplate":"variable=PVC BRL\u002ftonne\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PVC BRL\u002ftonne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PVC BRL\u002ftonne","orientation":"v","showlegend":true,"x":["2023-01-06T00:00:00","2023-01-13T00:00:00","2023-01-20T00:00:00","2023-01-27T00:00:00","2023-02-03T00:00:00","2023-02-10T00:00:00","2023-02-17T00:00:00","2023-02-24T00:00:00","2023-03-03T00:00:00","2023-03-10T00:00:00","2023-03-17T00:00:00","2023-03-24T00:00:00","2023-03-31T00:00:00","2023-04-07T00:00:00","2023-04-14T00:00:00","2023-04-21T00:00:00","2023-04-28T00:00:00","2023-05-05T00:00:00","2023-05-12T00:00:00","2023-05-19T00:00:00","2023-05-26T00:00:00","2023-06-02T00:00:00","2023-06-09T00:00:00","2023-06-16T00:00:00","2023-06-23T00:00:00","2023-06-30T00:00:00","2023-07-07T00:00:00","2023-07-14T00:00:00","2023-07-21T00:00:00","2023-07-28T00:00:00","2023-08-04T00:00:00","2023-08-11T00:00:00","2023-08-18T00:00:00","2023-08-25T00:00:00","2023-09-01T00:00:00","2023-09-08T00:00:00","2023-09-15T00:00:00","2023-09-22T00:00:00","2023-09-29T00:00:00","2023-10-06T00:00:00","2023-10-13T00:00:00","2023-10-20T00:00:00","2023-10-27T00:00:00","2023-11-03T00:00:00","2023-11-10T00:00:00","2023-11-17T00:00:00","2023-11-24T00:00:00","2023-12-01T00:00:00","2023-12-08T00:00:00","2023-12-15T00:00:00","2023-12-22T00:00:00"],"xaxis":"x","y":[5512.549,5349.321,5463.852,5346.214,5372.849,5509.855,5449.215,5452.896,5734.492,5676.905,5808.699,5773.011,5577.221,5562.439,5435.996,5553.64,5506.668,5448.002,5048.605,5109.561,5127.454,4834.779,4760.697,4708.677,4655.049,4690.726,4497.682,4437.178,4410.318,4375.568,4683.084,4721.961,5087.923,4997.237,5558.864,5600.101,5475.738,5528.735,5626.46,5792.752,5455.716,5412.065,5318.649,5254.663,5287.372,5259.53,5269.808,5721.037,5704.595,5734.472,5637.639],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MA12\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MA12","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MA12","orientation":"v","showlegend":true,"x":["2023-01-06T00:00:00","2023-01-13T00:00:00","2023-01-20T00:00:00","2023-01-27T00:00:00","2023-02-03T00:00:00","2023-02-10T00:00:00","2023-02-17T00:00:00","2023-02-24T00:00:00","2023-03-03T00:00:00","2023-03-10T00:00:00","2023-03-17T00:00:00","2023-03-24T00:00:00","2023-03-31T00:00:00","2023-04-07T00:00:00","2023-04-14T00:00:00","2023-04-21T00:00:00","2023-04-28T00:00:00","2023-05-05T00:00:00","2023-05-12T00:00:00","2023-05-19T00:00:00","2023-05-26T00:00:00","2023-06-02T00:00:00","2023-06-09T00:00:00","2023-06-16T00:00:00","2023-06-23T00:00:00","2023-06-30T00:00:00","2023-07-07T00:00:00","2023-07-14T00:00:00","2023-07-21T00:00:00","2023-07-28T00:00:00","2023-08-04T00:00:00","2023-08-11T00:00:00","2023-08-18T00:00:00","2023-08-25T00:00:00","2023-09-01T00:00:00","2023-09-08T00:00:00","2023-09-15T00:00:00","2023-09-22T00:00:00","2023-09-29T00:00:00","2023-10-06T00:00:00","2023-10-13T00:00:00","2023-10-20T00:00:00","2023-10-27T00:00:00","2023-11-03T00:00:00","2023-11-10T00:00:00","2023-11-17T00:00:00","2023-11-24T00:00:00","2023-12-01T00:00:00","2023-12-08T00:00:00","2023-12-15T00:00:00","2023-12-22T00:00:00"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,5537.488166666666,5542.8775,5560.63733333 ...

# %%
# extract month and year from dates**
data['Month'] = [i.month for i in data['Date']]
data['Year'] = [i.year for i in data['Date']]

# create a sequence of numbers
data['Series'] = nump.arange(1,len(data)+1)

# drop unnecessary columns and re-arrange
data.drop(['Date', 'MA12'], axis=1, inplace=True)
data = data[['Series', 'Year', 'Month', 'PVC BRL/tonne']] 

# check the head of the dataset**
data.head()
# Out:
#    Series  Year  Month  PVC BRL/tonne
# 0       1  2023      1       5512.549
# 1       2  2023      1       5349.321
# 2       3  2023      1       5463.852
# 3       4  2023      1       5346.214
# 4       5  2023      2       5372.849

# %%
# split data into train-test set
train = data[data['Month'] < 10]
test = data[data['Month'] >= 10]

# %%
# import the regression module**
from pycaret.regression import *

# initialize setup**
s = setup(data = train, test_data = test, target = 'PVC BRL/tonne', fold_strategy = 'timeseries', numeric_features = ['Month', 'Series'], fold = 3, transform_target = True, session_id = 123, data_split_shuffle = False, fold_shuffle = False)

# %%
best = compare_models(sort = 'MAE')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              09:24:54
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
prediction_holdout = predict_model(best);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 prediction_holdout = predict_model(best);
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\regression\functional.py:1895, in predict_model(estimator, data, round, verbose)
#    1892 if experiment is None:
#    1893     experiment = _EXPERIMENT_CLASS()
# -> 1895 return experiment.predict_model(
#    1896     estimator=estimator,
#    1897     data=data,
#    1898     round=round,
#    1899     verbose=verbose,
#    1900 )
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\regression\oop.py:2188, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2134 def predict_model(
#    2135     self,
#    2136     estimator,
#    (...)
#    2139     verbose: bool = True,
#    2140 ) -> pd.DataFrame:
#    2141     """
#    2142     This function predicts ``Label`` using a trained model. When ``data`` is
#    2143     None, it predicts label on the holdout set.
#    (...)
#    2185
#    2186     """
# -> 2188     return super().predict_model(
#    2189         estimator=estimator,
#    2190         data=data,
#    2191         probability_threshold=None,
#    2192         encoded_labels=False,
#    2193         round=round,
#    2194         verbose=verbose,
#    2195     )
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4984, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4981         probability_threshold = estimator.probability_threshold
#    4982     estimator = get_estimator_from_meta_estimator(estimator)
# -> 4984 pred = np.nan_to_num(estimator.predict(X_test_))
#    4985 pred = pipeline.inverse_transform(pred)
#    4986 # Need to convert labels back to numbers
#    4987 # TODO optimize
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\catboost\core.py:5851, in CatBoostRegressor.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5813 """
#    5814 Predict with data.
#    5815
#    (...)
#    5848     otherwise one-dimensional numpy.ndarray of formula return values for each object.
#    5849 """
#    5850 if prediction_type is None:
# -> 5851     prediction_type = self._get_default_prediction_type()
#    5852 return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\catboost\core.py:5945, in CatBoostRegressor._get_default_prediction_type(self)
#    5943 def _get_default_prediction_type(self):
#    5944     # TODO(ilyzhin) change on get_all_params after MLTOOLS-4758
# -> 5945     params = deepcopy(self._init_params)
#    5946     _process_synonyms(params)
#    5947     loss_function = params.get('loss_function')
#
# AttributeError: 'CatBoostRegressor' object has no attribute '_init_params'

# %%
# generate predictions on the original dataset**
predictions = predict_model(best, data=data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 # generate predictions on the original dataset**
# ----> 2 predictions = predict_model(best, data=data)
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\regression\functional.py:1895, in predict_model(estimator, data, round, verbose)
#    1892 if experiment is None:
#    1893     experiment = _EXPERIMENT_CLASS()
# -> 1895 return experiment.predict_model(
#    1896     estimator=estimator,
#    1897     data=data,
#    1898     round=round,
#    1899     verbose=verbose,
#    1900 )
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\regression\oop.py:2188, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2134 def predict_model(
#    2135     self,
#    2136     estimator,
#    (...)
#    2139     verbose: bool = True,
#    2140 ) -> pd.DataFrame:
#    2141     """
#    2142     This function predicts ``Label`` using a trained model. When ``data`` is
#    2143     None, it predicts label on the holdout set.
#    (...)
#    2185
#    2186     """
# -> 2188     return super().predict_model(
#    2189         estimator=estimator,
#    2190         data=data,
#    2191         probability_threshold=None,
#    2192         encoded_labels=False,
#    2193         round=round,
#    2194         verbose=verbose,
#    2195     )
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4984, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4981         probability_threshold = estimator.probability_threshold
#    4982     estimator = get_estimator_from_meta_estimator(estimator)
# -> 4984 pred = np.nan_to_num(estimator.predict(X_test_))
#    4985 pred = pipeline.inverse_transform(pred)
#    4986 # Need to convert labels back to numbers
#    4987 # TODO optimize
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\catboost\core.py:5851, in CatBoostRegressor.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5813 """
#    5814 Predict with data.
#    5815
#    (...)
#    5848     otherwise one-dimensional numpy.ndarray of formula return values for each object.
#    5849 """
#    5850 if prediction_type is None:
# -> 5851     prediction_type = self._get_default_prediction_type()
#    5852 return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File ~\anaconda3\envs\serie_temporal_best\lib\site-packages\catboost\core.py:5945, in CatBoostRegressor._get_default_prediction_type(self)
#    5943 def _get_default_prediction_type(self):
#    5944     # TODO(ilyzhin) change on get_all_params after MLTOOLS-4758
# -> 5945     params = deepcopy(self._init_params)
#    5946     _process_synonyms(params)
#    5947     loss_function = params.get('loss_function')
#
# AttributeError: 'CatBoostRegressor' object has no attribute '_init_params'

# %%
aux = pd.read_excel('PVC.xls', sheet_name='Para 2024')
aux['Date'] = pd.to_datetime(aux['Date'])

# Add date column to predictions
predictions['Date'] = aux['Date']

# check the result
data.head()
predictions.head()
# Out:
#    Series  Year  Month  PVC BRL/tonne  prediction_label       Date
# 0       1  2023      1    5512.548828       5512.543457 2023-01-06
# 1       2  2023      1    5349.320801       5349.325195 2023-01-13
# 2       3  2023      1    5463.852051       5463.845703 2023-01-20
# 3       4  2023      1    5346.213867       5346.219238 2023-01-27
# 4       5  2023      2    5372.849121       5372.848633 2023-02-03

# %%
# line plot**
fig = px.line(predictions, x='Date', y=["PVC BRL/tonne", "prediction_label"], template = 'plotly_dark')

# add a vertical rectange for test-set separation**
fig.add_vrect(x0="2023-01-01", x1="2023-12-01", fillcolor="grey", opacity=0.25, line_width=0)

fig.show()
# Out:
# <div>                            <div id="f5f7776b-0542-48c2-8426-ad266319a1bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5f7776b-0542-48c2-8426-ad266319a1bd")) {                    Plotly.newPlot(                        "f5f7776b-0542-48c2-8426-ad266319a1bd",                        [{"hovertemplate":"variable=PVC BRL\u002ftonne\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PVC BRL\u002ftonne","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PVC BRL\u002ftonne","orientation":"v","showlegend":true,"x":["2023-01-06T00:00:00","2023-01-13T00:00:00","2023-01-20T00:00:00","2023-01-27T00:00:00","2023-02-03T00:00:00","2023-02-10T00:00:00","2023-02-17T00:00:00","2023-02-24T00:00:00","2023-03-03T00:00:00","2023-03-10T00:00:00","2023-03-17T00:00:00","2023-03-24T00:00:00","2023-03-31T00:00:00","2023-04-07T00:00:00","2023-04-14T00:00:00","2023-04-21T00:00:00","2023-04-28T00:00:00","2023-05-05T00:00:00","2023-05-12T00:00:00","2023-05-19T00:00:00","2023-05-26T00:00:00","2023-06-02T00:00:00","2023-06-09T00:00:00","2023-06-16T00:00:00","2023-06-23T00:00:00","2023-06-30T00:00:00","2023-07-07T00:00:00","2023-07-14T00:00:00","2023-07-21T00:00:00","2023-07-28T00:00:00","2023-08-04T00:00:00","2023-08-11T00:00:00","2023-08-18T00:00:00","2023-08-25T00:00:00","2023-09-01T00:00:00","2023-09-08T00:00:00","2023-09-15T00:00:00","2023-09-22T00:00:00","2023-09-29T00:00:00","2023-10-06T00:00:00","2023-10-13T00:00:00","2023-10-20T00:00:00","2023-10-27T00:00:00","2023-11-03T00:00:00","2023-11-10T00:00:00","2023-11-17T00:00:00","2023-11-24T00:00:00","2023-12-01T00:00:00","2023-12-08T00:00:00","2023-12-15T00:00:00","2023-12-22T00:00:00"],"xaxis":"x","y":[5512.549,5349.321,5463.852,5346.214,5372.849,5509.855,5449.215,5452.896,5734.492,5676.905,5808.699,5773.011,5577.221,5562.439,5435.996,5553.64,5506.668,5448.002,5048.605,5109.561,5127.454,4834.779,4760.697,4708.677,4655.049,4690.726,4497.682,4437.178,4410.318,4375.568,4683.084,4721.961,5087.923,4997.237,5558.864,5600.101,5475.738,5528.735,5626.46,5792.752,5455.716,5412.065,5318.649,5254.663,5287.372,5259.53,5269.808,5721.037,5704.595,5734.472,5637.639],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=prediction_label\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"prediction_label","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"prediction_label","orientation":"v","showlegend":true,"x":["2023-01-06T00:00:00","2023-01-13T00:00:00","2023-01-20T00:00:00","2023-01-27T00:00:00","2023-02-03T00:00:00","2023-02-10T00:00:00","2023-02-17T00:00:00","2023-02-24T00:00:00","2023-03-03T00:00:00","2023-03-10T00:00:00","2023-03-17T00:00:00","2023-03-24T00:00:00","2023-03-31T00:00:00","2023-04-07T00:00:00","2023-04-14T00:00:00","2023-04-21T00:00:00","2023-04-28T00:00:00","2023-05-05T00:00:00","2023-05-12T00:00:00","2023-05-19T00:00:00","2023-05-26T00:00:00","2023-06-02T00:00:00","2023-06-09T00:00:00","2023-06-16T00:00:00","2023-06-23T00:00:00","2023-06-30T00:00:00","2023-07-07T00:00:00","2023-07-14T00:00:00","2023-07-21T00:00:00","2023-07-28T00:00:00","2023-08-04T00:00:00","2023-08-11T00:00:00","2023-08-18T00:00:00","2023-08-25T00:00:00","2023-09-01T00:00:00","2023-09-08T00:00:00","2023-09-15T00:00:00","2023-09-22T00:00:00","2023-09-29T00:00:00","2023-10-06T00:00:00","2023-10-13T00:00:00","2023-10-20T00:00:00","2023-10-27T00:00:00","2023-11-03T00:00:00","2023-11-10T00:00:00","2023-11-17T00:00:00","2023-11-24T00:00:00","2023-12-01T00:00:00","2023-12-08T00:00:00","2023-12-15T00:00:00","2023-12-22T00:00:00"],"xaxis":"x","y":[5512.5435,5349.325,5463.8457,5346.219,5372.8486,5509.8457,54 ...
